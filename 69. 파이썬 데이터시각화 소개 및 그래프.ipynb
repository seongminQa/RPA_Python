# %% [markdown]
# - 데이터 시각화 문법
# Matplotlib 데이터 시각화 기본문법
# Matplotlib 목적에 따라 그래프 그리기
# Matplotlib 스타일링 / 강조하기 기법
# Seaborn으로 편하게 그래프 그리기
#
# -> 데이터 시각화 프로젝트
# 공공 데이터 시각화 프로젝트

# %% [markdown]
# 데이터 시각화 해석
# -> 인사이트 도출
# 현상파악 ex) 나폴레옹 진군맵
# 원인도출 ex) 콜레라맵, 로즈다이어그램
# -> 추세파악 / 예측

# %% [markdown]
# 아나콘다에서는 맷플롯립이 이미 설치 되어있다.
# 다른 프로그램에서 이용하려면, 다운받아야한다.

# %% [markdown]
# # 라이브러리 임포트
# - matplotlib의 pyplot 모듈 사용
# - 관용적으로 plt이라는 별칭사용

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 기본 그래프 그리기
# - plt.plot(data)
# - plot에 데이터를 전달하여 그린다.

# %% [markdown]
# ## y축 데이터로 그리기
# - 1차원 리스트, 튜플, 시리즈 데이터를 전달하여 그린다.
# - x축은 데이터의 인덱스로 자동 지정된다.

# %% [markdown]
# ### 리스트 데이터로 그리기

# %%
# y축 데이터 [1,5,3,9,7]
data = [1,5,3,9,7]
data
# Out:
# [1, 5, 3, 9, 7]

# %%
# 그래프 그리기
plt.plot(data)

# %% [markdown]
# ### 시리즈 데이터로 그리기

# %%
# pandas import
import pandas as pd

# %%
# 시리즈 데이터 만들기 ([1,3,5,9,7])
s = pd.Series([1,5,3,9,7])
s
# Out:
# 0    1
# 1    5
# 2    3
# 3    9
# 4    7
# dtype: int64

# %%
# 그래프 그리기 (plot)
plt.plot(s)

# %%
# 시리즈 데이터의 인덱스 변경하기 : index = [10,20,30,40,50]
ss = pd.Series([1,5,3,9,7], index = [10,20,30,40,50])
ss
# Out:
# 10    1
# 20    5
# 30    3
# 40    9
# 50    7
# dtype: int64

# %%
plt.plot(ss)

# %%
# 시리즈 데이터의 인덱스 변경하기 : index = ['a','b','c','d','e']
sss = pd.Series([1,5,3,9,7], index = ['a','b','c','d','e'])
sss
# Out:
# a    1
# b    5
# c    3
# d    9
# e    7
# dtype: int64

# %%
plt.plot(sss)

# %% [markdown]
# ## x축, y축 데이터로  그리기
# - x축과 y축 데이터의 길이가 같아야 한다.

# %% [markdown]
# ### 리스트데이터로 그리기

# %%
x = [1,5,6,9,10]
y = [1,5,3,9,7]

# 그래프 그리기
plt.plot(x,y)

# %% [markdown]
# ### 데이터프레임 데이터로 그리기

# %%
sss = pd.DataFrame({'x':[1,5,6,9,10], 'y':[1,5,3,9,7]})
sss
# Out:
#     x  y
# 0   1  1
# 1   5  5
# 2   6  3
# 3   9  9
# 4  10  7

# %%
# 그래프 그리기
x = sss['x']
y = sss['y']
plt.plot(x,y)

# %% [markdown]
# ### 시리즈 데이터로 그리기

# %%
s = pd.Series([1,5,3,9,7])
s
# Out:
# 0    1
# 1    5
# 2    3
# 3    9
# 4    7
# dtype: int64

# %%
# 시리즈만 전달해서 그리기
plt.plot(s)
# plt.show()

# %%
# 시리즈만 전달해서 그리기
plt.plot(s)
plt.show() # 아웃풋을 보지 않고 그래프를 출력

# %%
# x,y 각각 전달해서 그리기
plt.plot(s.index, s)
